# %%
# 导入所需库
import pandas as pd

# 读取CSV文件（假设文件位于当前工作目录）
df = pd.read_csv('transactions_optimized.csv')

# 1. 查看数据集的基本形状（行数，列数）
print("数据集形状（行，列）:", df.shape)

# 2. 查看列名
print("\n列名列表:")
print(df.columns.tolist())

# 3. 查看每列的数据类型和非空值数量
print("\n数据集信息:")
df.info()

# 4. 查看前5行数据
print("\n前5行数据:")
df.head()

# 5. 查看后5行数据（可选）
print("\n后5行数据:")
df.tail()

# 6. 查看数值型列的统计摘要（计数、均值、标准差、分位数等）
print("\n数值列统计摘要:")
df.describe()

# 7. 检查缺失值情况
print("\n每列缺失值数量:")
df.isnull().sum()

# 8. 查看每列的唯一值数量（可选）
print("\n每列唯一值数量:")
df.nunique()

# 您可以根据需要继续探索，例如查看特定列的分布等
# Out:
# 数据集形状（行，列）: (60000, 45)
#
# 列名列表:
# ['transaction_id', 'order_date', 'year', 'month', 'week', 'day_of_week', 'quarter', 'is_holiday', 'marketplace', 'product_sku', 'category', 'subcategory', 'brand', 'price', 'discount_percent', 'final_price', 'cost', 'quantity_sold', 'revenue', 'cost_of_goods', 'commission_rate', 'total_platform_fees', 'advertising_cost', 'logistics_cost', 'profit', 'margin_percent', 'profit_per_item', 'region', 'city', 'city_tier', 'page_views', 'add_to_cart_count', 'conversion_rate', 'is_promo', 'product_rating', 'review_count', 'gross_margin', 'marketing_roi', 'ad_efficiency', 'views_to_purchase', 'price_segment', 'weekday_type', 'promo_price_diff', 'customer_value', 'text_features']
#
# 数据集信息:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 45 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   transaction_id       60000 non-null  int64
# ...
